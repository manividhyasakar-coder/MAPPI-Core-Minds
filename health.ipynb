# %%
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI

load_dotenv()

llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash")

# %%
with open("blood_work.txt", "r") as f:
    blood_report = f.read()

print(blood_report[:200])
# Out:
# Patient: Rajesh Sharma, Age 48, Male
# Date: May 7, 2026
#
# COMPLETE BLOOD COUNT (CBC)
# --------------------------
# Hemoglobin:        15.1 g/dL        (Normal: 13.5â€“17.5)
# Hematocrit:        44%

# %%
extraction_prompt = f"""
You are a medical data extraction assistant.

From the blood report below, extract ALL test values and classify each one as HIGH, LOW, or NORMAL 
based on the reference ranges provided in the report.

Format your response as:
- Test Name: value | Status: HIGH/LOW/NORMAL | Reference: range

Blood Report:
{blood_report}
"""

extraction_response = llm.invoke(extraction_prompt)
extracted_values = extraction_response.text

print("=== STAGE 1: EXTRACTED VALUES ===")
print(extracted_values)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# File ~\Desktop\MAPPI Core\.venv\Lib\site-packages\langchain_google_genai\chat_models.py:3194, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3193 try:
# -> 3194     response: GenerateContentResponse = self.client.models.generate_content(
#    3195         **request,
#    3196     )
#    3197 except ClientError as e:
#
# File ~\Desktop\MAPPI Core\.venv\Lib\site-packages\google\genai\models.py:6454, in Models.generate_content(self, model, contents, config)
#    6453 i += 1
# -> 6454 response = self._generate_content(
#    6455     model=model, contents=contents, config=parsed_config
#    6456 )
#    6458 function_map = _extra_utils.get_function_map(parsed_config)
#
# File ~\Desktop\MAPPI Core\.venv\Lib\site-packages\google\genai\models.py:4890, in Models._generate_content(self, model, contents, config)
#    4888 request_dict = _common.encode_unserializable_types(request_dict)
# -> 4890 response = self._api_client.request(
#    4891     'post', path, request_dict, http_options
#    4892 )
#    4894 if config is not None and getattr(
#    4895     config, 'should_return_http_response', None
#    4896 ):
#
# File ~\Desktop\MAPPI Core\.venv\Lib\site-packages\google\genai\_api_client.py:1611, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1608 http_request = self._build_request(
#    1609     http_method, path, request_dict, http_options
#    1610 )
# -> 1611 response = self._request(http_request, http_options, stream=False)
#    1612 response_body = (
#    1613     response.response_stream[0] if response.response_stream else ''
#    1614 )
#
# File ~\Desktop\MAPPI Core\.venv\Lib\site-packages\google\genai\_api_client.py:1402, in BaseApiClient._request(self, http_request, http_options, stream)
#    1401     retry = tenacity.Retrying(**retry_kwargs)
# -> 1402     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
#    1404 return self._retry(self._request_once, http_request, stream)
#
# File ~\Desktop\MAPPI Core\.venv\Lib\site-packages\tenacity\__init__.py:470, in Retrying.__call__(self, fn, *args, **kwargs)
#     469 while True:
# --> 470     do = self.iter(retry_state=retry_state)
#     471     if isinstance(do, DoAttempt):
#
# File ~\Desktop\MAPPI Core\.venv\Lib\site-packages\tenacity\__init__.py:371, in BaseRetrying.iter(self, retry_state)
#     370 for action in self.iter_state.actions:
# --> 371     result = action(retry_state)
#     372 return result
#
# File ~\Desktop\MAPPI Core\.venv\Lib\site-packages\tenacity\__init__.py:393, in BaseRetrying._post_retry_check_actions.<locals>.<lambda>(rs)
#     392 if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 393     self._add_action_func(lambda rs: rs.outcome.result())
#     394     return
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\concurrent\futures\_base.py:443, in Future.result(self, timeout)
#     442 elif self._state == FINISHED:
# --> 443     return self.__get_result()
#     445 self._condition.wait(timeout)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\concurrent\futures\_base.py:395, in Future.__get_result(self)
#     394 try:
# --> 395     raise self._exception
#     396 finally:
#     397     # Break a reference cycle with the exception in self._exception
#
# File ~\Desktop\MAPPI Core\.venv\Lib\site-packages\tenacity\__init__.py:473, in Retrying.__call__(self, fn, *args, **kwargs)
#     472 try:
# --> 473     result = fn(*args, **kwargs)
#     474 except BaseException:  # noqa: B902
#
# File ~\Desktop\MAPPI Core\.venv\Lib\site-packages\google\genai\_api_client.py:1381, in BaseApiClient._request_once(self, http_request, stream)
#    1380   response = self._httpx_client.send(httpx_request, stream=stream)  # type: ignore[union-attr]
# -> 1381 errors.APIError.raise_for_response(response)
#    1382 return HttpResponse(
#    1383     response.headers, response if stream else [response.text]
#    1384 )
#
# File ~\Desktop\MAPPI Core\.venv\Lib\site-packages\google\genai\errors.py:155, in APIError.raise_for_response(cls, response)
#     153   response_json = response.body_segments[0].get('error', {})
# --> 155 cls.raise_error(response.status_code, response_json, response)
#
# File ~\Desktop\MAPPI Core\.venv\Lib\site-packages\google\genai\errors.py:184, in APIError.raise_error(cls, status_code, response_json, response)
#     183 if 400 <= status_code < 500:
# --> 184   raise ClientError(status_code, response_json, response)
#     185 elif 500 <= status_code < 600:
#
# ClientError: 403 PERMISSION_DENIED. {'error': {'code': 403, 'message': 'Your project has been denied access. Please contact support.', 'status': 'PERMISSION_DENIED'}}
#
# The above exception was the direct cause of the following exception:
#
# ChatGoogleGenerativeAIError               Traceback (most recent call last)
# Cell In[10], line 14
#      10 Blood Report:
#      11 {blood_report}
#      12 """
#      13
# ---> 14 extraction_response = llm.invoke(extraction_prompt)
#      15 extracted_values = extraction_response.text
#      16
#      17 print("=== STAGE 1: EXTRACTED VALUES ===")
#
# File ~\Desktop\MAPPI Core\.venv\Lib\site-packages\langchain_google_genai\chat_models.py:2672, in ChatGoogleGenerativeAI.invoke(self, input, config, code_execution, stop, **kwargs)
#    2669         msg = "Tools are already defined.code_execution tool can't be defined"
#    2670         raise ValueError(msg)
# -> 2672 return super().invoke(input, config, stop=stop, **kwargs)
#
# File ~\Desktop\MAPPI Core\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:474, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     460 @override
#     461 def invoke(
#     462     self,
#    (...)    467     **kwargs: Any,
#     468 ) -> AIMessage:
#     469     config = ensure_config(config)
#     470     return cast(
#     471         "AIMessage",
#     472         cast(
#     473             "ChatGeneration",
# --> 474             self.generate_prompt(
#     475                 [self._convert_input(input)],
#     476                 stop=stop,
#     477                 callbacks=config.get("callbacks"),
#     478                 tags=config.get("tags"),
#     479                 metadata=config.get("metadata"),
#     480                 run_name=config.get("run_name"),
#     481                 run_id=config.pop("run_id", None),
#     482                 **kwargs,
#     483             ).generations[0][0],
#     484         ).message,
#     485     )
#
# File ~\Desktop\MAPPI Core\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1823, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1814 @override
#    1815 def generate_prompt(
#    1816     self,
#    (...)   1820     **kwargs: Any,
#    1821 ) -> LLMResult:
#    1822     prompt_messages = [p.to_messages() for p in prompts]
# -> 1823     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~\Desktop\MAPPI Core\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1630, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1627 for i, m in enumerate(input_messages):
#    1628     try:
#    1629         results.append(
# -> 1630             self._generate_with_cache(
#    1631                 m,
#    1632                 stop=stop,
#    1633                 run_manager=run_managers[i] if run_managers else None,
#    1634                 **kwargs,
#    1635             )
#    1636         )
#    1637     except BaseException as e:
#    1638         if run_managers:
#
# File ~\Desktop\MAPPI Core\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1970, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1968     result = generate_from_stream(iter(chunks))
#    1969 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1970     result = self._generate(
#    1971         messages, stop=stop, run_manager=run_manager, **kwargs
#    1972     )
#    1973 else:
#    1974     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~\Desktop\MAPPI Core\.venv\Lib\site-packages\langchain_google_genai\chat_models.py:3198, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3194     response: GenerateContentResponse = self.client.models.generate_content(
#    3195         **request,
#    3196     )
#    3197 except ClientError as e:
# -> 3198     _handle_client_error(e, request)
#    3200 return _response_to_result(response)
#
# File ~\Desktop\MAPPI Core\.venv\Lib\site-packages\langchain_google_genai\chat_models.py:169, in _handle_client_error(e, request)
#     167 model_name = request.get("model", "unknown")
#     168 msg = f"Error calling model '{model_name}' ({e.status}): {e}"
# --> 169 raise ChatGoogleGenerativeAIError(msg) from e
#
# ChatGoogleGenerativeAIError: Error calling model 'gemini-2.5-flash' (PERMISSION_DENIED): 403 PERMISSION_DENIED. {'error': {'code': 403, 'message': 'Your project has been denied access. Please contact support.', 'status': 'PERMISSION_DENIED'}}

# %%
diet_prompt = f"""
You are a clinical nutritionist specializing in Indian dietary habits.

Based on the blood work analysis below, write:
1. A short health summary in 4-5 lines explaining the patient's condition in simple language
2. A short, practical Indian diet plan having only two sections (1) Foods to avoid (2) Foods to eat more of. 
   Do not include any other sections in diet plan.

Blood Work Analysis:
{extracted_values}
"""

diet_response = llm.invoke(diet_prompt)

print("=== STAGE 2: HEALTH SUMMARY & DIET PLAN ===")
print(diet_response.text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 10
#       6 2. A short, practical Indian diet plan having only two sections (1) Foods to avoid (2) Foods to eat more of.
#       7    Do not include any other sections in diet plan.
#       8
#       9 Blood Work Analysis:
# ---> 10 {extracted_values}
#      11 """
#      12
#      13 diet_response = llm.invoke(diet_prompt)
#
# NameError: name 'extracted_values' is not defined
